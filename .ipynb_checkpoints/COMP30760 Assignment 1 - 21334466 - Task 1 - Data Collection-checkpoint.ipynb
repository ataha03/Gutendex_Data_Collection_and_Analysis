# %% [markdown]
# # COMP30760 Assignment 1 - 21334466 - Task 1 - Data Collection
#
# For this task, I will be collecting data from Gutendex - a digital library of books available from Project Gutenberg. Gutendex offers an accessible and simple API for extracting information on books.
#
# Here is the API endpoint from the list of APIs - https://gutendex.com/.
#
# I decided to extract the data from the first 1000 URLs on the API endpoint, resulting in an extensive dataset of over 31,000 book entries.
#
# The large volume of data will be very useful for the data cleaning and analysis process. By opting for a broad and inclusive dataset, I hope to explore accurate patterns, trends, and insight that emerge across genres, authors, and other useful characteristics.

# %%
#Importing libraries
import json, urllib.request
from pathlib import Path

# %%
#Setting API URL
gutendexUrl = "https://gutendex.com/books"

#List of pages of data
gutendex_metadata = []

# %%
#Creating directory for raw data storage, if it doesn't exist
dir_raw = Path("raw")
dir_raw.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Data Collection and Parsing
#
# To collect data from the Gutendex API, I will define a custom function specifically for fetching information from the API endpoint.
#
# The API endpoint is organized into distinct URL pages, with each page presenting a subset of the available data.
#
# For example, the first page of the API can be accessed via the following URL: "https://gutendex.com/books/?page=1".
#
# Each page retrieved from the API is formatted as a dictionary or JSON object, containing the following key attributes:
#
# - "count": Indicates the total number of book entries on the current page.
# - "next": Provides the URL of the next page, allowing for sequential data retrieval.
# - "previous": Specifies the URL of the previous page, facilitating backward navigation if necessary.
# - "results": Represents the book entries as a list of dictionaries, containing detailed information about individual books.
#
# The data collection process involves iterating over the available page numbers. For each page, the function will read the data, extract and parse relevant information, and save it for subsequent analysis.

# %%
#General function to retrieve and parse data, takes URL and page number as input
def fetch_and_parse(endpoint, pageNumber=1): #default to first page
    #construct url
    url = endpoint
    
    if (not endpoint.startswith("/")):
         url += "/"
    if (pageNumber > 0):
        url += "?page=%d" % pageNumber
        print("Fetching %s" % url)
    else:
        print("Invalid page number %d. Must be a positive number." % pageNumber)
        return
    
    try:
        response = urllib.request.urlopen(url)
        jdata = response.read().decode()
        return json.loads(jdata)
    except:
        print("Failed to fetch %s" % url)

# %%
#Fetch + parse gutendex json data
#I have taken the first 1000 pages, here is a demonstration of the first 5:
for i in range(1, 6):
    gutendex = fetch_and_parse(gutendexUrl, i)
    gutendex_metadata.append(gutendex)
    if (gutendex["next"] == ""):
        #if next url is empty, stop fetching data
        break
# Out:
# Fetching https://gutendex.com/books/?page=1
# Fetching https://gutendex.com/books/?page=2
# Fetching https://gutendex.com/books/?page=3
# Fetching https://gutendex.com/books/?page=4
# Fetching https://gutendex.com/books/?page=5

# %% [markdown]
# ## Data Access
#
# Each book entry in the "results" field follows this structured format:
#
# - id: Unique book identifier.
# - title: Book title.
# - authors: List of dictionaries of authors, where each dictionary contains an author's name, birth year, and death year.
# - translators: List of dictionaries of translators.
# - subjects: Genres and subjects.
# - bookshelves: Categories the book belongs to.
# - languages: Available languages.
# - copyright: Indicates copyright status.
# - media_type: Type of media (e.g."Text").
# - formats: List of dictionaries of different file formats with corresponding URLs.
# - download_count: Number of downloads.

# %% [markdown]
# Example of accessing an entry:
#
# 1) Accessing the results of the first page [0]
#
# 2) Looking at the result of entries ["results"]
#
# 3) Choosing the first book entry [0]
#
# 4) Retrieving its title ["title"]

# %%
#Example of accessing a title of a book entry
gutendex_metadata[0]["results"][0]["title"]
# Out:
# 'Romeo and Juliet'

# %% [markdown]
# ## Data Saving
#
# Next, I will create individual files to store the extraced data.
#
# Each file is named after its corresponding page URL, and contains the data collected from that page. This organisation ensures that raw dataset remains structured and easily accessible for further analysis.
#
# In total, this will create 1000 distinct files of the Gutendex dataset.

# %%
#Function to write page of data into raw dataset directory
def write_to_dataset(index, offset):
    #ensure index is a number + a valid number
    try:
        gutendex_metadata[int(index)]["results"][0]
    except:
        print("Invalid Page Number Index: %d\nIndex must be an integer and less than %d (number of pages retrieved)" % (index, len(gutendex_metadata)))
    #create filename and write to dataset
    fname="gutendex_page_%s.json" % (offset + 1)
    out_path = dir_raw / fname
    print("Writing data to %s" % out_path)
    fout = open(out_path, "w")
    json.dump(gutendex_metadata[index]["results"], fout, indent=4)
    fout.close()

# %% [markdown]
# To be able to collect more data, I added a variable "offset". At first, I gathered data from 10 pages to test and understand the dataset. Later on, the offset was adjusted to collect data from 30, then 500, and ultimately 1000 pages.
#
# The offset allowed me to accumulate more files seamlessly without disrupting the existing dataset.

# %%
offset = 500
for page in range(len(gutendex_metadata)):
    write_to_dataset(page, offset)
    offset += 1
# Out:
# Writing data to raw\gutendex_page_501.json
# Writing data to raw\gutendex_page_502.json
# Writing data to raw\gutendex_page_503.json
# Writing data to raw\gutendex_page_504.json
# Writing data to raw\gutendex_page_505.json
# Writing data to raw\gutendex_page_506.json
# Writing data to raw\gutendex_page_507.json
# Writing data to raw\gutendex_page_508.json
# Writing data to raw\gutendex_page_509.json
# Writing data to raw\gutendex_page_510.json
# Writing data to raw\gutendex_page_511.json
# Writing data to raw\gutendex_page_512.json
# Writing data to raw\gutendex_page_513.json
# Writing data to raw\gutendex_page_514.json
# Writing data to raw\gutendex_page_515.json
# Writing data to raw\gutendex_page_516.json
# Writing data to raw\gutendex_page_517.json
# Writing data to raw\gutendex_page_518.json
# Writing data to raw\gutendex_page_519.json
# Writing data to raw\gutendex_page_520.json
# Writing data to raw\gutendex_page_521.json
# Writing data to raw\gutendex_page_522.json
# Writing data to raw\gutendex_page_523.json
# Writing data to raw\gutendex_page_524.json
# Writing data to raw\gutendex_page_525.json
# Writing data to raw\gutendex_page_526.json
# Writing data to raw\gutendex_page_527.json
# Writing data to raw\gutendex_page_528.json
# Writing data to raw\gutendex_page_529.json
# Writing data to raw\gutendex_page_530.json
# Writing data to raw\gutendex_page_531.json
# Writing data to raw\gutendex_page_532.json
# Writing data to raw\gutendex_page_533.json
# Writing data to raw\gutendex_page_534.json
# Writing data to raw\gutendex_page_535.json
# Writing data to raw\gutendex_page_536.json
# Writing data to raw\gutendex_page_537.json
# Writing data to raw\gutendex_page_538.json
# Writing data to raw\gutendex_page_539.json
# Writing data to raw\gutendex_page_540.json
# Writing data to raw\gutendex_page_541.json
# Writing data to raw\gutendex_page_542.json
# Writing data to raw\gutendex_page_543.json
# Writing data to raw\gutendex_page_544.json
# Writing data to raw\gutendex_page_545.json
# Writing data to raw\gutendex_page_546.json
# Writing data to raw\gutendex_page_547.json
# Writing data to raw\gutendex_page_548.json
# Writing data to raw\gutendex_page_549.json
# Writing data to raw\gutendex_page_550.json
# Writing data to raw\gutendex_page_551.json
# Writing data to raw\gutendex_page_552.json
# Writing data to raw\gutendex_page_553.json
# Writing data to raw\gutendex_page_554.json
# Writing data to raw\gutendex_page_555.json
# Writing data to raw\gutendex_page_556.json
# Writing data to raw\gutendex_page_557.json
# Writing data to raw\gutendex_page_558.json
# Writing data to raw\gutendex_page_559.json
# Writing data to raw\gutendex_page_560.json
# Writing data to raw\gutendex_page_561.json
# Writing data to raw\gutendex_page_562.json
# Writing data to raw\gutendex_page_563.json
# Writing data to raw\gutendex_page_564.json
# Writing data to raw\gutendex_page_565.json
# Writing data to raw\gutendex_page_566.json
# Writing data to raw\gutendex_page_567.json
# Writing data to raw\gutendex_page_568.json
# Writing data to raw\gutendex_page_569.json
# Writing data to raw\gutendex_page_570.json
# Writing data to raw\gutendex_page_571.json
# Writing data to raw\gutendex_page_572.json
# Writing data to raw\gutendex_page_573.json
# Writing data to raw\gutendex_page_574.json
# Writing data to raw\gutendex_page_575.json
# Writing data to raw\gutendex_page_576.json
# Writing data to raw\gutendex_page_577.json
# Writing data to raw\gutendex_page_578.json
# Writing data to raw\gutendex_page_579.json
# Writing data to raw\gutendex_page_580.json
# Writing data to raw\gutendex_page_581.json
# Writing data to raw\gutendex_page_582.json
# Writing data to raw\gutendex_page_583.json
# Writing data to raw\gutendex_page_584.json
# Writing data to raw\gutendex_page_585.json
# Writing data to raw\gutendex_page_586.json
# Writing data to raw\gutendex_page_587.json
# Writing data to raw\gutendex_page_588.json
# Writing data to raw\gutendex_page_589.json
# Writing data to raw\gutendex_page_590.json
# Writing data to raw\gutendex_page_591.json
# Writing data to raw\gutendex_page_592.json
# Writing data to raw\gutendex_page_593.json
# Writing data to raw\gutendex_page_594.json
# Writing data to raw\gutendex_page_595.json
# Writing data to raw\gutendex_page_596.json
# Writing data to raw\gutendex_page_597.json
# Writing data to raw\gutendex_page_598.json
# Writing data to raw\gutendex_page_599.json
# Writing data to raw\gutendex_page_600.json
# Writing data to raw\gutendex_page_601.json
# Writing data to raw\gutendex_page_602.json
# Writing data to raw\gutendex_page_603.json
# Writing data to raw\gutendex_page_604.json
# Writing data to raw\gutendex_page_605.json
# Writing data to raw\gutendex_page_606.json
# Writing data to raw\gutendex_page_607.json
# Writing data to raw\gutendex_page_608.json
# Writing data to raw\gutendex_page_609.json
# Writing data to raw\gutendex_page_610.json
# Writing data to raw\gutendex_page_611.json
# Writing data to raw\gutendex_page_612.json
# Writing data to raw\gutendex_page_613.json
# Writing data to raw\gutendex_page_614.json
# Writing data to raw\gutendex_page_615.json
# Writing data to raw\gutendex_page_616.json
# Writing data to raw\gutendex_page_617.json
# Writing data to raw\gutendex_page_618.json
# Writing data to raw\gutendex_page_619.json
# Writing data to raw\gutendex_page_620.json
# Writing data to raw\gutendex_page_621.json
# Writing data to raw\gutendex_page_622.json
# Writing data to raw\gutendex_page_623.json
# Writing data to raw\gutendex_page_624.json
# Writing data to raw\gutendex_page_625.json
# Writing data to raw\gutendex_page_626.json
# Writing data to raw\gutendex_page_627.json
# Writing data to raw\gutendex_page_628.json
# Writing data to raw\gutendex_page_629.json
# Writing data to raw\gutendex_page_630.json
# Writing data to raw\gutendex_page_631.json
# Writing data to raw\gutendex_page_632.json
# Writing data to raw\gutendex_page_633.json
# Writing data to raw\gutendex_page_634.json
# Writing data to raw\gutendex_page_635.json
# Writing data to raw\gutendex_page_636.json
# Writing data to raw\gutendex_page_637.json
# Writing data to raw\gutendex_page_638.json
# Writing data to raw\gutendex_page_639.json
# Writing data to raw\gutendex_page_640.json
# Writing data to raw\gutendex_page_641.json
# Writing data to raw\gutendex_page_642.json
# Writing data to raw\gutendex_page_643.json
# Writing data to raw\gutendex_page_644.json
# Writing data to raw\gutendex_page_645.json
# Writing data to raw\gutendex_page_646.json
# Writing data to raw\gutendex_page_647.json
# Writing data to raw\gutendex_page_648.json
# Writing data to raw\gutendex_page_649.json
# Writing data to raw\gutendex_page_650.json
# Writing data to raw\gutendex_page_651.json
# Writing data to raw\gutendex_page_652.json
# Writing data to raw\gutendex_page_653.json
# Writing data to raw\gutendex_page_654.json
# Writing data to raw\gutendex_page_655.json
# Writing data to raw\gutendex_page_656.json
# Writing data to raw\gutendex_page_657.json
# Writing data to raw\gutendex_page_658.json
# Writing data to raw\gutendex_page_659.json
# Writing data to raw\gutendex_page_660.json
# Writing data to raw\gutendex_page_661.json
# Writing data to raw\gutendex_page_662.json
# Writing data to raw\gutendex_page_663.json
# Writing data to raw\gutendex_page_664.json
# Writing data to raw\gutendex_page_665.json
# Writing data to raw\gutendex_page_666.json
# Writing data to raw\gutendex_page_667.json
# Writing data to raw\gutendex_page_668.json
# Writing data to raw\gutendex_page_669.json
# Writing data to raw\gutendex_page_670.json
# Writing data to raw\gutendex_page_671.json
# Writing data to raw\gutendex_page_672.json
# Writing data to raw\gutendex_page_673.json
# Writing data to raw\gutendex_page_674.json
# Writing data to raw\gutendex_page_675.json
# Writing data to raw\gutendex_page_676.json
# Writing data to raw\gutendex_page_677.json
# Writing data to raw\gutendex_page_678.json
# Writing data to raw\gutendex_page_679.json
# Writing data to raw\gutendex_page_680.json
# Writing data to raw\gutendex_page_681.json
# Writing data to raw\gutendex_page_682.json
# Writing data to raw\gutendex_page_683.json
# Writing data to raw\gutendex_page_684.json
# Writing data to raw\gutendex_page_685.json
# Writing data to raw\gutendex_page_686.json
# Writing data to raw\gutendex_page_687.json
# Writing data to raw\gutendex_page_688.json
# Writing data to raw\gutendex_page_689.json
# Writing data to raw\gutendex_page_690.json
# Writing data to raw\gutendex_page_691.json
# Writing data to raw\gutendex_page_692.json
# Writing data to raw\gutendex_page_693.json
# Writing data to raw\gutendex_page_694.json
# Writing data to raw\gutendex_page_695.json
# Writing data to raw\gutendex_page_696.json
# Writing data to raw\gutendex_page_697.json
# Writing data to raw\gutendex_page_698.json
# Writing data to raw\gutendex_page_699.json
# Writing data to raw\gutendex_page_700.json
# Writing data to raw\gutendex_page_701.json
# Writing data to raw\gutendex_page_702.json
# Writing data to raw\gutendex_page_703.json
# Writing data to raw\gutendex_page_704.json
# Writing data to raw\gutendex_page_705.json
# Writing data to raw\gutendex_page_706.json
# Writing data to raw\gutendex_page_707.json
# Writing data to raw\gutendex_page_708.json
# Writing data to raw\gutendex_page_709.json
# Writing data to raw\gutendex_page_710.json
# Writing data to raw\gutendex_page_711.json
# Writing data to raw\gutendex_page_712.json
# Writing data to raw\gutendex_page_713.json
# Writing data to raw\gutendex_page_714.json
# Writing data to raw\gutendex_page_715.json
# Writing data to raw\gutendex_page_716.json
# Writing data to raw\gutendex_page_717.json
# Writing data to raw\gutendex_page_718.json
# Writing data to raw\gutendex_page_719.json
# Writing data to raw\gutendex_page_720.json
# Writing data to raw\gutendex_page_721.json
# Writing data to raw\gutendex_page_722.json
# Writing data to raw\gutendex_page_723.json
# Writing data to raw\gutendex_page_724.json
# Writing data to raw\gutendex_page_725.json
# Writing data to raw\gutendex_page_726.json
# Writing data to raw\gutendex_page_727.json
# Writing data to raw\gutendex_page_728.json
# Writing data to raw\gutendex_page_729.json
# Writing data to raw\gutendex_page_730.json
# Writing data to raw\gutendex_page_731.json
# Writing data to raw\gutendex_page_732.json
# Writing data to raw\gutendex_page_733.json
# Writing data to raw\gutendex_page_734.json
# Writing data to raw\gutendex_page_735.json
# Writing data to raw\gutendex_page_736.json
# Writing data to raw\gutendex_page_737.json
# Writing data to raw\gutendex_page_738.json
# Writing data to raw\gutendex_page_739.json
# Writing data to raw\gutendex_page_740.json
# Writing data to raw\gutendex_page_741.json
# Writing data to raw\gutendex_page_742.json
# Writing data to raw\gutendex_page_743.json
# Writing data to raw\gutendex_page_744.json
# Writing data to raw\gutendex_page_745.json
# Writing data to raw\gutendex_page_746.json
# Writing data to raw\gutendex_page_747.json
# Writing data to raw\gutendex_page_748.json
# Writing data to raw\gutendex_page_749.json
# Writing data to raw\gutendex_page_750.json
# Writing data to raw\gutendex_page_751.json
# Writing data to raw\gutendex_page_752.json
# Writing data to raw\gutendex_page_753.json
# Writing data to raw\gutendex_page_754.json
# Writing data to raw\gutendex_page_755.json
# Writing data to raw\gutendex_page_756.json
# Writing data to raw\gutendex_page_757.json
# Writing data to raw\gutendex_page_758.json
# Writing data to raw\gutendex_page_759.json
# Writing data to raw\gutendex_page_760.json
# Writing data to raw\gutendex_page_761.json
# Writing data to raw\gutendex_page_762.json
# Writing data to raw\gutendex_page_763.json
# Writing data to raw\gutendex_page_764.json
# Writing data to raw\gutendex_page_765.json
# Writing data to raw\gutendex_page_766.json
# Writing data to raw\gutendex_page_767.json
# Writing data to raw\gutendex_page_768.json
# Writing data to raw\gutendex_page_769.json
# Writing data to raw\gutendex_page_770.json
# Writing data to raw\gutendex_page_771.json
# Writing data to raw\gutendex_page_772.json
# Writing data to raw\gutendex_page_773.json
# Writing data to raw\gutendex_page_774.json
# Writing data to raw\gutendex_page_775.json
# Writing data to raw\gutendex_page_776.json
# Writing data to raw\gutendex_page_777.json
# Writing data to raw\gutendex_page_778.json
# Writing data to raw\gutendex_page_779.json
# Writing data to raw\gutendex_page_780.json
# Writing data to raw\gutendex_page_781.json
# Writing data to raw\gutendex_page_782.json
# Writing data to raw\gutendex_page_783.json
# Writing data to raw\gutendex_page_784.json
# Writing data to raw\gutendex_page_785.json
# Writing data to raw\gutendex_page_786.json
# Writing data to raw\gutendex_page_787.json
# Writing data to raw\gutendex_page_788.json
# Writing data to raw\gutendex_page_789.json
# Writing data to raw\gutendex_page_790.json
# Writing data to raw\gutendex_page_791.json
# Writing data to raw\gutendex_page_792.json
# Writing data to raw\gutendex_page_793.json
# Writing data to raw\gutendex_page_794.json
# Writing data to raw\gutendex_page_795.json
# Writing data to raw\gutendex_page_796.json
# Writing data to raw\gutendex_page_797.json
# Writing data to raw\gutendex_page_798.json
# Writing data to raw\gutendex_page_799.json
# Writing data to raw\gutendex_page_800.json
# Writing data to raw\gutendex_page_801.json
# Writing data to raw\gutendex_page_802.json
# Writing data to raw\gutendex_page_803.json
# Writing data to raw\gutendex_page_804.json
# Writing data to raw\gutendex_page_805.json
# Writing data to raw\gutendex_page_806.json
# Writing data to raw\gutendex_page_807.json
# Writing data to raw\gutendex_page_808.json
# Writing data to raw\gutendex_page_809.json
# Writing data to raw\gutendex_page_810.json
# Writing data to raw\gutendex_page_811.json
# Writing data to raw\gutendex_page_812.json
# Writing data to raw\gutendex_page_813.json
# Writing data to raw\gutendex_page_814.json
# Writing data to raw\gutendex_page_815.json
# Writing data to raw\gutendex_page_816.json
# Writing data to raw\gutendex_page_817.json
# Writing data to raw\gutendex_page_818.json
# Writing data to raw\gutendex_page_819.json
# Writing data to raw\gutendex_page_820.json
# Writing data to raw\gutendex_page_821.json
# Writing data to raw\gutendex_page_822.json
# Writing data to raw\gutendex_page_823.json
# Writing data to raw\gutendex_page_824.json
# Writing data to raw\gutendex_page_825.json
# Writing data to raw\gutendex_page_826.json
# Writing data to raw\gutendex_page_827.json
# Writing data to raw\gutendex_page_828.json
# Writing data to raw\gutendex_page_829.json
# Writing data to raw\gutendex_page_830.json
# Writing data to raw\gutendex_page_831.json
# Writing data to raw\gutendex_page_832.json
# Writing data to raw\gutendex_page_833.json
# Writing data to raw\gutendex_page_834.json
# Writing data to raw\gutendex_page_835.json
# Writing data to raw\gutendex_page_836.json
# Writing data to raw\gutendex_page_837.json
# Writing data to raw\gutendex_page_838.json
# Writing data to raw\gutendex_page_839.json
# Writing data to raw\gutendex_page_840.json
# Writing data to raw\gutendex_page_841.json
# Writing data to raw\gutendex_page_842.json
# Writing data to raw\gutendex_page_843.json
# Writing data to raw\gutendex_page_844.json
# Writing data to raw\gutendex_page_845.json
# Writing data to raw\gutendex_page_846.json
# Writing data to raw\gutendex_page_847.json
# Writing data to raw\gutendex_page_848.json
# Writing data to raw\gutendex_page_849.json
# Writing data to raw\gutendex_page_850.json
# Writing data to raw\gutendex_page_851.json
# Writing data to raw\gutendex_page_852.json
# Writing data to raw\gutendex_page_853.json
# Writing data to raw\gutendex_page_854.json
# Writing data to raw\gutendex_page_855.json
# Writing data to raw\gutendex_page_856.json
# Writing data to raw\gutendex_page_857.json
# Writing data to raw\gutendex_page_858.json
# Writing data to raw\gutendex_page_859.json
# Writing data to raw\gutendex_page_860.json
# Writing data to raw\gutendex_page_861.json
# Writing data to raw\gutendex_page_862.json
# Writing data to raw\gutendex_page_863.json
# Writing data to raw\gutendex_page_864.json
# Writing data to raw\gutendex_page_865.json
# Writing data to raw\gutendex_page_866.json
# Writing data to raw\gutendex_page_867.json
# Writing data to raw\gutendex_page_868.json
# Writing data to raw\gutendex_page_869.json
# Writing data to raw\gutendex_page_870.json
# Writing data to raw\gutendex_page_871.json
# Writing data to raw\gutendex_page_872.json
# Writing data to raw\gutendex_page_873.json
# Writing data to raw\gutendex_page_874.json
# Writing data to raw\gutendex_page_875.json
# Writing data to raw\gutendex_page_876.json
# Writing data to raw\gutendex_page_877.json
# Writing data to raw\gutendex_page_878.json
# Writing data to raw\gutendex_page_879.json
# Writing data to raw\gutendex_page_880.json
# Writing data to raw\gutendex_page_881.json
# Writing data to raw\gutendex_page_882.json
# Writing data to raw\gutendex_page_883.json
# Writing data to raw\gutendex_page_884.json
# Writing data to raw\gutendex_page_885.json
# Writing data to raw\gutendex_page_886.json
# Writing data to raw\gutendex_page_887.json
# Writing data to raw\gutendex_page_888.json
# Writing data to raw\gutendex_page_889.json
# Writing data to raw\gutendex_page_890.json
# Writing data to raw\gutendex_page_891.json
# Writing data to raw\gutendex_page_892.json
# Writing data to raw\gutendex_page_893.json
# Writing data to raw\gutendex_page_894.json
# Writing data to raw\gutendex_page_895.json
# Writing data to raw\gutendex_page_896.json
# Writing data to raw\gutendex_page_897.json
# Writing data to raw\gutendex_page_898.json
# Writing data to raw\gutendex_page_899.json
# Writing data to raw\gutendex_page_900.json
# Writing data to raw\gutendex_page_901.json
# Writing data to raw\gutendex_page_902.json
# Writing data to raw\gutendex_page_903.json
# Writing data to raw\gutendex_page_904.json
# Writing data to raw\gutendex_page_905.json
# Writing data to raw\gutendex_page_906.json
# Writing data to raw\gutendex_page_907.json
# Writing data to raw\gutendex_page_908.json
# Writing data to raw\gutendex_page_909.json
# Writing data to raw\gutendex_page_910.json
# Writing data to raw\gutendex_page_911.json
# Writing data to raw\gutendex_page_912.json
# Writing data to raw\gutendex_page_913.json
# Writing data to raw\gutendex_page_914.json
# Writing data to raw\gutendex_page_915.json
# Writing data to raw\gutendex_page_916.json
# Writing data to raw\gutendex_page_917.json
# Writing data to raw\gutendex_page_918.json
# Writing data to raw\gutendex_page_919.json
# Writing data to raw\gutendex_page_920.json
# Writing data to raw\gutendex_page_921.json
# Writing data to raw\gutendex_page_922.json
# Writing data to raw\gutendex_page_923.json
# Writing data to raw\gutendex_page_924.json
# Writing data to raw\gutendex_page_925.json
# Writing data to raw\gutendex_page_926.json
# Writing data to raw\gutendex_page_927.json
# Writing data to raw\gutendex_page_928.json
# Writing data to raw\gutendex_page_929.json
# Writing data to raw\gutendex_page_930.json
# Writing data to raw\gutendex_page_931.json
# Writing data to raw\gutendex_page_932.json
# Writing data to raw\gutendex_page_933.json
# Writing data to raw\gutendex_page_934.json
# Writing data to raw\gutendex_page_935.json
# Writing data to raw\gutendex_page_936.json
# Writing data to raw\gutendex_page_937.json
# Writing data to raw\gutendex_page_938.json
# Writing data to raw\gutendex_page_939.json
# Writing data to raw\gutendex_page_940.json
# Writing data to raw\gutendex_page_941.json
# Writing data to raw\gutendex_page_942.json
# Writing data to raw\gutendex_page_943.json
# Writing data to raw\gutendex_page_944.json
# Writing data to raw\gutendex_page_945.json
# Writing data to raw\gutendex_page_946.json
# Writing data to raw\gutendex_page_947.json
# Writing data to raw\gutendex_page_948.json
# Writing data to raw\gutendex_page_949.json
# Writing data to raw\gutendex_page_950.json
# Writing data to raw\gutendex_page_951.json
# Writing data to raw\gutendex_page_952.json
# Writing data to raw\gutendex_page_953.json
# Writing data to raw\gutendex_page_954.json
# Writing data to raw\gutendex_page_955.json
# Writing data to raw\gutendex_page_956.json
# Writing data to raw\gutendex_page_957.json
# Writing data to raw\gutendex_page_958.json
# Writing data to raw\gutendex_page_959.json
# Writing data to raw\gutendex_page_960.json
# Writing data to raw\gutendex_page_961.json
# Writing data to raw\gutendex_page_962.json
# Writing data to raw\gutendex_page_963.json
# Writing data to raw\gutendex_page_964.json
# Writing data to raw\gutendex_page_965.json
# Writing data to raw\gutendex_page_966.json
# Writing data to raw\gutendex_page_967.json
# Writing data to raw\gutendex_page_968.json
# Writing data to raw\gutendex_page_969.json
# Writing data to raw\gutendex_page_970.json
# Writing data to raw\gutendex_page_971.json
# Writing data to raw\gutendex_page_972.json
# Writing data to raw\gutendex_page_973.json
# Writing data to raw\gutendex_page_974.json
# Writing data to raw\gutendex_page_975.json
# Writing data to raw\gutendex_page_976.json
# Writing data to raw\gutendex_page_977.json
# Writing data to raw\gutendex_page_978.json
# Writing data to raw\gutendex_page_979.json
# Writing data to raw\gutendex_page_980.json
# Writing data to raw\gutendex_page_981.json
# Writing data to raw\gutendex_page_982.json
# Writing data to raw\gutendex_page_983.json
# Writing data to raw\gutendex_page_984.json
# Writing data to raw\gutendex_page_985.json
# Writing data to raw\gutendex_page_986.json
# Writing data to raw\gutendex_page_987.json
# Writing data to raw\gutendex_page_988.json
# Writing data to raw\gutendex_page_989.json
# Writing data to raw\gutendex_page_990.json
# Writing data to raw\gutendex_page_991.json
# Writing data to raw\gutendex_page_992.json
# Writing data to raw\gutendex_page_993.json
# Writing data to raw\gutendex_page_994.json
# Writing data to raw\gutendex_page_995.json
# Writing data to raw\gutendex_page_996.json
# Writing data to raw\gutendex_page_997.json
# Writing data to raw\gutendex_page_998.json
# Writing data to raw\gutendex_page_999.json
# Writing data to raw\gutendex_page_1000.json

# %% [markdown]
# In summary, the data collection process has yielded an organised dataset of 1000 files.
#
# This can now be used for detailed exploration and analysis into literary trends and reader preferences.
